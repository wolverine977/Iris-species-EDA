# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
kl =pd.read_csv("C:/Users/mayan/Desktop/Iris.csv")

# %%
kl.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.scatterplot(x="SepalLengthCm", y="PetalLengthCm",data=kl, hue="Species")
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
sns.scatterplot(x="SepalLengthCm", y="PetalLengthCm",data=kl, hue="PetalLengthCm")
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
sns.set_style("dark")   #fro the dark theme
sns.histplot(kl['PetalLengthCm'], kde=True)   #now its both with the bars and curve
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='Count'>

# %%
sns.kdeplot(kl['PetalLengthCm'], shade=True)   #here we have the curve only for varying petal length
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='Density'>

# %%
sns.histplot(data=kl, x='PetalLengthCm', hue='Species')
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='Count'>

# %%
sns.kdeplot(data=kl, x='PetalLengthCm', hue='Species', shade=True)
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='Density'>
